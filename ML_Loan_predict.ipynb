# %% [markdown]
# ## Loan Status Prediction using ML Models:

# %% [markdown]
# ### Dataset Information:
#
# - 'York City Bank' Housing Finance deals in all kinds of home loans. They have presence across all urban, semi-urban, and rural areas.
# - The customer first applies for loans, and after that, the company validates loan eligibility.
# - YCB Bank wants to automate the loan eligibility process based on the customer details provided while filling out the online application form.
# - To automate this process, they have to identify the customer segments that are eligible for a home loan, so that they can specifically target these customers.
# - This is a standard "Supervised Classification" task where we have to predict whether a loan would be approved or not as (Y/N).
# - Below are the dataset attributes with descriptions:
#
# 1. **Loan_ID**: Unique Loan ID
# 2. **Gender**: Male/ Female
# 3. **Married**: (Y/N)
# 4. **Dependents**: Number of dependents
# 5. **Education**: Applicant Education (Graduate/Undergraduate)
# 6. **Self_Employed**: (Y/N)
# 7. **ApplicantIncome**: Applicant income
# 8. **CoapplicantIncome**: Coapplicant income
# 9. **LoanAmount**: Loan amount in thousands of dollars
# 10. **Loan_Amount_Term**: Term of loan in months
# 11. **Credit_History**: Credit history meets guidelines, yes or no
# 12. **Property_Area**: Urban/ Semi Urban/ Rural
# 13. **Loan_Status**: Loan approved (Y/N). 'This is the target variable.'

# %%
# !mamba install pandas
# !mamba install numpy
# !mamba install seaborn
# !mamba install scikit-learn
# !mamba install matplotlib
# Out:
# mambajs 0.19.13
#
# Specs: xeus-python, numpy, matplotlib, pillow, ipywidgets>=8.1.6, ipyleaflet, scipy, pandas
# Channels: emscripten-forge, conda-forge
#
# Solving environment...
# Solving took 10.30339999999851 seconds
#   Name                          Version                       Build                         Channel
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# + pandas                        3.0.2                         np22py313h9d9dc1e_0           emscripten-forge
# + python-tzdata                 2026.1                        pyhd8ed1ab_0                  conda-forge
# - pip                           25.3                          pyh145f28c_0                  conda-forge
# mambajs 0.19.13
#
# Specs: xeus-python, numpy, matplotlib, pillow, ipywidgets>=8.1.6, ipyleaflet, scipy, pandas
# Channels: emscripten-forge, conda-forge
#
# Solving environment...
# Solving took 7.86639999999851 seconds
# ...

# %% [markdown]
# #### Importing required Python Libraries:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
loan_data = pd.read_csv('loan_db.csv')
loan_data.head(4)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y

# %%
loan_data.tail(4)
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N

# %%
print('Number of Rows:', loan_data.shape[0])
print('Number of Columns:',loan_data.shape[1])
# Out:
# Number of Rows: 614
# Number of Columns: 13

# %%
loan_data.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %% [markdown]
# #### Converting required 'Dtype' from str to object:

# %%
loan_data['Loan_ID'] = loan_data['Loan_ID'].astype('object')
loan_data['Married'] = loan_data['Married'].astype('object')
loan_data['Dependents'] = loan_data['Dependents'].astype('object')
loan_data['Education'] = loan_data['Education'].astype('object')
loan_data['Self_Employed'] = loan_data['Self_Employed'].astype('object')
loan_data['Property_Area'] = loan_data['Property_Area'].astype('object')
loan_data['Loan_Status'] = loan_data['Loan_Status'].astype('object')

# %%
loan_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    str
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(7), str(1)
# memory usage: 43.2+ KB

# %% [markdown]
# #### Handling Missing (or) Null Values

# %%
loan_data.isnull().sum()*100 / len(loan_data)
# Out:
# Loan_ID              0.000000
# Gender               2.117264
# Married              0.488599
# Dependents           2.442997
# Education            0.000000
# Self_Employed        5.211726
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           3.583062
# Loan_Amount_Term     2.280130
# Credit_History       8.143322
# Property_Area        0.000000
# Loan_Status          0.000000
# dtype: float64

# %%
loan_data = loan_data.drop(['Loan_ID'], axis = 1)

# %%
loan_data.head(3)
# Out:
#   Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0  Graduate            No             5849
# 1   Male     Yes          1  Graduate            No             4583
# 2   Male     Yes          0  Graduate           Yes             3000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0         NaN             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N
# 2         Urban           Y

# %%
columns = ['Gender', 'Dependents', 'LoanAmount', 'Loan_Amount_Term']

# %%
loan_data = loan_data.dropna(subset = columns)

# %%
loan_data.isnull().sum()*100 / len(loan_data)
# Out:
# Gender               0.000000
# Married              0.000000
# Dependents           0.000000
# Education            0.000000
# Self_Employed        5.424955
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           0.000000
# Loan_Amount_Term     0.000000
# Credit_History       8.679928
# Property_Area        0.000000
# Loan_Status          0.000000
# dtype: float64

# %%
loan_data['Self_Employed'].mode()[0]
# Out:
# 'No'

# %%
loan_data['Self_Employed'] = loan_data['Self_Employed'].fillna(loan_data['Self_Employed'].mode()[0])

# %%
loan_data['Credit_History'].unique()
# Out:
# array([ 1.,  0., nan])

# %%
loan_data['Credit_History'].mode()[0]
# Out:
# np.float64(1.0)

# %%
loan_data['Credit_History'] = loan_data['Credit_History'].fillna(loan_data['Credit_History'].mode()[0])

# %%
loan_data.isnull().sum()*100 / len(loan_data)
# Out:
# Gender               0.0
# Married              0.0
# Dependents           0.0
# Education            0.0
# Self_Employed        0.0
# ApplicantIncome      0.0
# CoapplicantIncome    0.0
# LoanAmount           0.0
# Loan_Amount_Term     0.0
# Credit_History       0.0
# Property_Area        0.0
# Loan_Status          0.0
# dtype: float64

# %%
plt.figure(figsize=(5, 4))  # wider chart
sns.countplot(x ='Gender', data = loan_data, palette ={'Male':'orange','Female':'pink'})
# Out:
# /tmp/xpython_42/993948738.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x ='Gender', data = loan_data, palette ={'Male':'orange','Female':'pink'})
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(loan_data['Loan_Status'])
plt.figure(figsize=(5, 4))

# %%
sns.countplot(
    x ='Married',
    data =loan_data,
    palette={'Yes': 'blue', 'No': 'orange'})
# Out:
# /tmp/xpython_42/1761301860.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(
# <Axes: xlabel='Married', ylabel='count'>

# %%
sns.countplot(loan_data['Dependents'])
# Out:
# <Axes: xlabel='count', ylabel='Dependents'>

# %% [markdown]
# #### Log Transformation:

# %%
plt.figure(figsize=(5, 4))  # wider chart
sns.displot(x ='ApplicantIncome', data = loan_data)

# %% [markdown]
# #### Handling Categorical cols:

# %%
loan_data.sample(4)
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 260    Male     Yes          1      Graduate            No             6083
# 497    Male     Yes          0      Graduate            No             4625
# 37   Female     Yes          0      Graduate            No             3667
# 259    Male     Yes         3+  Not Graduate            No             4931
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 260             4250.0       330.0             360.0             1.0
# 497             2857.0       111.0              12.0             1.0
# 37              1459.0       144.0             360.0             1.0
# 259                0.0       128.0             360.0             1.0
#
#     Property_Area Loan_Status
# 260         Urban           Y
# 497         Urban           Y
# 37      Semiurban           Y
# 259     Semiurban           N

# %%
loan_data['Dependents']
# Out:
# 1       1
# 2       0
# 3       0
# 4       0
# 5       2
#        ..
# 609     0
# 610    3+
# 611     1
# 612     2
# 613     0
# Name: Dependents, Length: 553, dtype: object

# %%
loan_data['Dependents'] = loan_data['Dependents'].replace(to_replace="3+",value='4')

# %%
loan_data['Dependents'].unique()
# Out:
# array(['1', '0', '2', '4'], dtype=object)

# %%
loan_data['Loan_Status'].unique()
loan_data['Gender'].unique()
# Out:
# <StringArray>
# ['Male', 'Female']
# Length: 2, dtype: str

# %%
loan_data['Gender'] = loan_data['Gender'].map({'Male': 1, 'Female': 0}).astype('int')
loan_data['Property_Area'] = loan_data['Property_Area'].map({'Rural':0,'Semiurban':2,'Urban':1}).astype('int')
loan_data['Loan_Status'] = loan_data['Loan_Status'].map({'Y':1,'N':0}).astype('int')
loan_data['Education'] = loan_data['Education'].map({'Graduate':1,'Not Graduate':0}).astype('int')
loan_data['Married'] = loan_data['Married'].map({'Yes':1,'No':0}).astype('int')
loan_data['Self_Employed'] = loan_data['Self_Employed'].map({'Yes':1,'No':0}).astype('int')

# %%
loan_data['Loan_Status'].unique()
# Out:
# array([0, 1])

# %%
loan_data['Gender'].unique()
# Out:
# array([1, 0])

# %%
loan_data.head(3)
# Out:
#    Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 1       1        1          1          1              0             4583
# 2       1        1          0          1              1             3000
# 3       1        1          0          0              0             2583
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
#
#    Property_Area  Loan_Status
# 1              0            0
# 2              1            1
# 3              1            1

# %%
corr = loan_data.corr()
plt.figure(figsize=(10, 7))  # wider chart
sns.heatmap(corr, annot = True, cmap ='BuPu')
# Out:
# <Axes: >

# %% [markdown]
# #### Store feature Matrix in X and response (Target) in Vector Y:

# %%
X = loan_data.drop('Loan_Status', axis = 1)

# %%
X.head(4)
# Out:
#    Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 1       1        1          1          1              0             4583
# 2       1        1          0          1              1             3000
# 3       1        1          0          0              0             2583
# 4       1        0          0          1              0             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#    Property_Area
# 1              0
# 2              1
# 3              1
# 4              1

# %%
y = loan_data['Loan_Status']

# %%
y
# Out:
# 1      0
# 2      1
# 3      1
# 4      1
# 5      1
#       ..
# 609    1
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Loan_Status, Length: 553, dtype: int32

# %% [markdown]
# #### Feature Scaling:

# %%
loan_data.head(3)
# Out:
#    Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 1       1        1          1          1              0             4583
# 2       1        1          0          1              1             3000
# 3       1        1          0          0              0             2583
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
#
#    Property_Area  Loan_Status
# 1              0            0
# 2              1            1
# 3              1            1

# %%
cols = ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term']

# %%
from sklearn.preprocessing import StandardScaler
st = StandardScaler()
X[cols] = st.fit_transform(X[cols])

# %%
X.head()
# Out:
#    Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 1       1        1          1          1              0        -0.128694
# 2       1        1          0          1              1        -0.394296
# 3       1        1          0          0              0        -0.464262
# 4       1        0          0          1              0         0.109057
# 5       1        1          2          1              1         0.011239
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1          -0.049699   -0.214368          0.279961             1.0
# 2          -0.545638   -0.952675          0.279961             1.0
# 3           0.229842   -0.309634          0.279961             1.0
# 4          -0.545638   -0.059562          0.279961             1.0
# 5           0.834309    1.440866          0.279961             1.0
#
#    Property_Area
# 1              0
# 2              1
# 3              1
# 4              1
# 5              1

# %% [markdown]
# #### Splitting The Dataset Into Training Set - Test Set & Applying K-Fold Cross Validation:

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

# %% [markdown]
# #### Model Training - train_test_split

# %%
model_df={}
def model_val(model,X,y):
    X_train, X_test, y_train, y_test = train_test_split(X,y,
                                                    test_size =0.20,
                                                    random_state =42)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print(f"{model} accuracy is {accuracy_score(y_test, y_pred)}")

    #5-fold Cross-Validation:
    score = cross_val_score(model, X, y, cv = 5)
    print(f"{model} Avg cross val score is {np.round(np.mean(score),3):.3f}")
    model_df[model]= round(np.mean(score)*100,2)

# %% [markdown]
# #### 1. Logistic Regression:

# %%
loan_data.head(3)
# Out:
#    Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 1       1        1          1          1              0             4583
# 2       1        1          0          1              1             3000
# 3       1        1          0          0              0             2583
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
#
#    Property_Area  Loan_Status
# 1              0            0
# 2              1            1
# 3              1            1

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model_val(model,X,y)
# Out:
# LogisticRegression() accuracy is 0.8018018018018018
# LogisticRegression() Avg cross val score is 0.805

# %%
model_df
# Out:
# {LogisticRegression(): np.float64(80.48)}

# %% [markdown]
# #### 2. Support Vector Classifier (SVC):

# %%
from sklearn import svm
model = svm.SVC()
model_val(model,X,y)
# Out:
# SVC() accuracy is 0.7927927927927928
# SVC() Avg cross val score is 0.794

# %% [markdown]
# #### 3. Decision Tree Classifier:

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model_val(model,X,y)
# Out:
# DecisionTreeClassifier() accuracy is 0.6936936936936937
# DecisionTreeClassifier() Avg cross val score is 0.714

# %%
model_df
# Out:
# {LogisticRegression(): np.float64(80.48),
#  SVC(): np.float64(79.39),
#  DecisionTreeClassifier(): np.float64(71.43)}

# %% [markdown]
# #### 4. Random Forest Classifier:

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model_val(model,X,y)
# Out:
# RandomForestClassifier() accuracy is 0.7747747747747747
# RandomForestClassifier() Avg cross val score is 0.783

# %% [markdown]
# #### 5. Gradient Boosting Classifier:

# %%
from sklearn.ensemble import GradientBoostingClassifier
model =GradientBoostingClassifier()
model_val(model,X,y)
# Out:
# GradientBoostingClassifier() accuracy is 0.7927927927927928
# GradientBoostingClassifier() Avg cross val score is 0.772

# %% [markdown]
# #### 6. Extra Trees Classifier:

# %%
from sklearn.ensemble import ExtraTreesClassifier
model = ExtraTreesClassifier()
model_val(model,X,y)
# Out:
# ExtraTreesClassifier() accuracy is 0.7117117117117117
# ExtraTreesClassifier() Avg cross val score is 0.756

# %% [markdown]
# #### 7. Gaussian Naive Bayes (GaussianNB):

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model_val(model,X,y)
# Out:
# GaussianNB() accuracy is 0.8288288288288288
# GaussianNB() Avg cross val score is 0.787

# %% [markdown]
# #### Conclusion: Logistic Regression is the best model with 80.48 %

# %%
model_df
# Out:
# {LogisticRegression(): np.float64(80.48),
#  SVC(): np.float64(79.39),
#  DecisionTreeClassifier(): np.float64(71.43),
#  RandomForestClassifier(): np.float64(78.3),
#  GradientBoostingClassifier(): np.float64(77.22),
#  ExtraTreesClassifier(): np.float64(75.58),
#  GaussianNB(): np.float64(78.67)}

# %% [markdown]
# #### Performing 'Hyperparameter' Tuning (for better accuracy):

# %%
from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# #### 1. Tune 'Hyper Parameter' for Logistic Regression:

# %%
log_reg_grid = {"C":np.logspace(-4,4,20),
             "solver":['liblinear']}

# %%
rs_log_reg = RandomizedSearchCV(LogisticRegression(),
                  param_distributions = log_reg_grid,
                  n_iter =20, cv =5, verbose =True)

# %%
rs_log_reg.fit(X,y)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# RandomizedSearchCV(cv=5, estimator=LogisticRegression(), n_iter=20,
#                    param_distributions={'C': array([1.00000000e-04, 2.63665090e-04, 6.95192796e-04, 1.83298071e-03,
#        4.83293024e-03, 1.27427499e-02, 3.35981829e-02, 8.85866790e-02,
#        2.33572147e-01, 6.15848211e-01, 1.62377674e+00, 4.28133240e+00,
#        1.12883789e+01, 2.97635144e+01, 7.84759970e+01, 2.06913808e+02,
#        5.45559478e+02, 1.43844989e+03, 3.79269019e+03, 1.00000000e+04]),
#                                         'solver': ['liblinear']},
#                    verbose=True)

# %%
rs_log_reg.best_score_
# Out:
# np.float64(0.8047829647829647)

# %%
rs_log_reg.best_params_
# Out:
# {'solver': 'liblinear', 'C': np.float64(0.23357214690901212)}

# %% [markdown]
# #### 2.'Hyper Parameter' tuning for SVC:

# %%
svc_grid = {'C':[0.25,0.50,0.75,1],"kernel":["linear"]}

# %%
rs_svc = RandomizedSearchCV(svm.SVC(), param_distributions =svc_grid, cv =5,
                   n_iter = 20, verbose = True)

# %%
rs_svc.fit(X,y)
# Out:
# /lib/python3.13/site-packages/sklearn/model_selection/_search.py:324: UserWarning: The total space of parameters 4 is smaller than n_iter=20. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# RandomizedSearchCV(cv=5, estimator=SVC(), n_iter=20,
#                    param_distributions={'C': [0.25, 0.5, 0.75, 1],
#                                         'kernel': ['linear']},
#                    verbose=True)

# %%
rs_svc.best_score_
# Out:
# np.float64(0.8066011466011467)

# %% [markdown]
# #### 3. 'Hyper Parameter' tuning for Random Forest Classifier:

# %%
RandomForestClassifier()
# Out:
# RandomForestClassifier()

# %%
rf_grid = {'n_estimators':np.arange(10,1000,10),
           'max_features':['auto','sqrt'],
           'max_depth':[None,3,5,10,20,30],
           'min_samples_split':[2,5,20,50,100],
           'min_samples_leaf':[1,2,5,10]
 }

# %%
rs_rf = RandomizedSearchCV(RandomForestClassifier(), param_distributions = rf_grid,
                   cv=5, n_iter=20, verbose =True)

# %%
rs_rf.fit(X,y)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# /lib/python3.13/site-packages/sklearn/model_selection/_validation.py:490: FitFailedWarning:
# 50 fits failed out of a total of 100.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 50 fits failed with the following error:
# Traceback (most recent call last):
#   File "/lib/python3.13/site-packages/sklearn/model_selection/_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/lib/python3.13/site-packages/sklearn/base.py", line 1329, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
# ...

# %%
rs_rf.best_params_
# Out:
# {'n_estimators': np.int32(820),
#  'min_samples_split': 20,
#  'min_samples_leaf': 10,
#  'max_features': 'sqrt',
#  'max_depth': 10}

# %%
rs_rf.best_score_
# Out:
# np.float64(0.8066175266175266)

# %% [markdown]
# #### 4. 'Hyper Parameter' tuning for Gaussian_NB:

# %%
gaussian_grid = {"var_smoothing": np.logspace(-9, -1, 20),
                 "priors": [None]  # or specify class priors if you want
                }

# %%
rs_gaussian = RandomizedSearchCV(GaussianNB(), param_distributions = gaussian_grid, cv = 5,
                   n_iter = 20, verbose = True)

# %%
rs_gaussian.fit(X,y)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# RandomizedSearchCV(cv=5, estimator=GaussianNB(), n_iter=20,
#                    param_distributions={'priors': [None],
#                                         'var_smoothing': array([1.00000000e-09, 2.63665090e-09, 6.95192796e-09, 1.83298071e-08,
#        4.83293024e-08, 1.27427499e-07, 3.35981829e-07, 8.85866790e-07,
#        2.33572147e-06, 6.15848211e-06, 1.62377674e-05, 4.28133240e-05,
#        1.12883789e-04, 2.97635144e-04, 7.84759970e-04, 2.06913808e-03,
#        5.45559478e-03, 1.43844989e-02, 3.79269019e-02, 1.00000000e-01])},
#                    verbose=True)

# %%
print("Best parameters:", rs_gaussian.best_params_)
# Out:
# Best parameters: {'var_smoothing': np.float64(1e-09), 'priors': None}

# %%
rs_gaussian.best_score_
# Out:
# np.float64(0.7866830466830466)

# %% [markdown]
# #### Results Comparison:

# %%
LogisticRegression score Before Hyperparameter Tuning: 80.48
LogisticRegression score after Hyperparameter Tuning: 80.48 
    
------------------------------------------------------
SVC score Before Hyperparameter Tuning: 79.38
SVC score after Hyperparameter Tuning: 80.66
    
--------------------------------------------------------
RandomForestClassifier score Before Hyperparameter Tuning: 77.76
RandomForestClassifier score after Hyperparameter Tuning: 80.66

# %% [markdown]
# ##### Random Forest Classifier had the greatest improvement in accuracy.
# ##### So, will select 'Random Forest Classifier' model for production !!

# %% [markdown]
# #### Let's train our best Model (RFC) on the entire Loan Dataset:

# %%
X = loan_data.drop('Loan_Status',axis=1)
y = loan_data['Loan_Status']

# %%
rf = RandomForestClassifier(n_estimators = 390, min_samples_split = 50,
   min_samples_leaf = 2,
   max_features = 'sqrt',
   max_depth = 5)

# %%
rf.fit(X,y)
# Out:
# RandomForestClassifier(max_depth=5, min_samples_leaf=2, min_samples_split=50,
#                        n_estimators=390)

# %% [markdown]
# #### Save the Model:

# %%
import joblib

# %%
joblib.dump(rf,'loan_status_prediction')
# Out:
# ['loan_status_prediction']

# %%
main_model = joblib.load('loan_status_prediction')

# %%
main_model
# Out:
# RandomForestClassifier(max_depth=5, min_samples_leaf=2, min_samples_split=50,
#                        n_estimators=390)

# %% [markdown]
# #### GUI

# %%
# from tkinter import *
# import joblib
# import pandas as pd

# %%
# def show_entry():
    
#     p1 = float(e1.get())
#     p2 = float(e2.get())
#     p3 = float(e3.get())
#     p4 = float(e4.get())
#     p5 = float(e5.get())
#     p6 = float(e6.get())
#     p7 = float(e7.get())
#     p8 = float(e8.get())
#     p9 = float(e9.get())
#     p10 = float(e10.get())
#     p11 = float(e11.get())
    
#     model = joblib.load('loan_status_prediction')
#     df = pd.DataFrame({
#     'Gender':p1,
#     'Married':p2,
#     'Dependents':p3,
#     'Education':p4,
#     'Self_Employed':p5,
#     'ApplicantIncome':p6,
#     'CoapplicantIncome':p7,
#     'LoanAmount':p8,
#     'Loan_Amount_Term':p9,
#     'Credit_History':p10,
#     'Property_Area':p11
# },index=[0])
#     result = model.predict(df)
    
#     if result == 1:
#         Label(master, text="Loan approved").grid(row=31)
#     else:
#         Label(master, text="Loan Not Approved").grid(row=31)
        
    
# # master =Tk()
# master.title("Loan Status Prediction Using Machine Learning")
# label = Label(master,text = "Loan Status Prediction",bg = "black",
#                fg = "white").grid(row=0,columnspan=2)

# Label(master,text = "Gender [1:Male ,0:Female]").grid(row=1)
# Label(master,text = "Married [1:Yes,0:No]").grid(row=2)
# Label(master,text = "Dependents [1,2,3,4]").grid(row=3)
# Label(master,text = "Education").grid(row=4)
# Label(master,text = "Self_Employed").grid(row=5)
# Label(master,text = "ApplicantIncome").grid(row=6)
# Label(master,text = "CoapplicantIncome").grid(row=7)
# Label(master,text = "LoanAmount").grid(row=8)
# Label(master,text = "Loan_Amount_Term").grid(row=9)
# Label(master,text = "Credit_History").grid(row=10)
# Label(master,text = "Property_Area").grid(row=11)


# e1 = Entry(master)
# e2 = Entry(master)
# e3 = Entry(master)
# e4 = Entry(master)
# e5 = Entry(master)
# e6 = Entry(master)
# e7 = Entry(master)
# e8 = Entry(master)
# e9 = Entry(master)
# e10 = Entry(master)
# e11 = Entry(master)


# e1.grid(row=1,column=1)
# e2.grid(row=2,column=1)
# e3.grid(row=3,column=1)
# e4.grid(row=4,column=1)
# e5.grid(row=5,column=1)
# e6.grid(row=6,column=1)
# e7.grid(row=7,column=1)
# e8.grid(row=8,column=1)
# e9.grid(row=9,column=1)
# e10.grid(row=10,column=1)
# e11.grid(row=11,column=1)

# Button(master,text="Predict",command=show_entry).grid()

# mainloop()
